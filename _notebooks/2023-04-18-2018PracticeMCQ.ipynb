# %% [markdown]
# # APCSP Practice MCQ 2018 Test + Corrections
#
# - toc: false
# - badges: true
# - comments: true
# - categories: [jupyter, python, tri3, misc]

# %% [markdown]
# ## Evidence of Test Taken:
# I got a 62 out of 66 on the test, which was a higher score than I expected to get. I will be discussing the questions that I got wrong and how I felt about the test overall.
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ## Thoughts on the Test:
# I did way better than I expected and compared to the previous College Board Multiple Choice Quizzes, I understood much more material and it took me much less time. A lot of the questions, I realized, were topics covered in the weeks prior where we learned about other Big Ideas, learned about certain topics and had group/class discussions.

# %% [markdown]
# ## Corrections for Incorrect Questions:
#
# #### Question 24: The table below shows the time a computer system...
#
# ![image.png](attachment:image.png)
#
# I got this question wrong because I incorrectly assumed that based on the information in the table, deleting entries from data is likely to take the longest amount of time when scaled up for a very large company of approximately 100,000 customers, when sorting data actually takes the longest to complete.
#
# #### Question 35: Consequence of an undecidable problem
#
# ![image.png](attachment:image-2.png)
#
# I got this question wrong because I incorrectly assumed that there are several different possible algorithms that can solve this problem, but there is controversy about which is the most efficient. There is no possible algorithm for solving an undecidable problem, and there will always be instances that are unsolvable.
#
# #### Question 46: Draw figure using drawLine procedure
#
# ![image.png](attachment:image-3.png)
#
# I got this question wrong because in my selected choice, the first call to drawLine draws a line segment with endpoints (1, 5) and (6, 5). The second call to drawLine draws a line segment with endpoints (1, 5) and (8, 7). The third call to drawLine draws a line segment with endpoints (1, 5) and (8, 3). This does not create the shown figure, and choice B has the correct calls to draw the figure.

# %% [markdown]
# ### Reflection:
#
# Overall, I think I did great on this multiple choice quiz. Last time, it took me a lot of more time to digest what the questions were asking and then understand how I could even decide the answer. I understood the majority of the topics on this quiz almost after a minute or two with multiple reads. From the last multiple choice, I feel like I have actually learned a lot more, even if it is the most basic knowledge. Before this quiz I was really discouraged about my progress and felt like I have not really learned much or made any progress, but from my results and the way I got through this quiz, I think I am on track so far in APCSP.
